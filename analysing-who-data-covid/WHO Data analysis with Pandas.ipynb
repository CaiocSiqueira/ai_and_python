# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# data available in: https://covid19.who.int/WHO-covid19-global-data.csv

# %%
data = pd.read_csv(r"C:\Users\caio_\Desktop\sample_project\.ipynb_checkpoints\WHO-COVID-19-global-data.csv")
data
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 264961    2023-01-20           ZW     Zimbabwe       AFRO          0
# 264962    2023-01-21           ZW     Zimbabwe       AFRO          0
# 264963    2023-01-22           ZW     Zimbabwe       AFRO          0
# 264964    2023-01-23           ZW     Zimbabwe       AFRO          0
# 264965    2023-01-24           ZW     Zimbabwe       AFRO          0
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 0                      0           0                  0
# ...

# %%
# See all countries listed in the data

data['Country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia (Plurinational State of)', 'Bonaire',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Cayman Islands', 'Central African Republic', 'Chad',
#        'Chile', 'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', 'Côte d’Ivoire', 'Croatia', 'Cuba', 'Curaçao',
#        'Cyprus', 'Czechia', "Democratic People's Republic of Korea",
#        'Democratic Republic of the Congo', 'Denmark', 'Djibouti',
# ...

# %%
# See all the regions listed in the data

data['WHO_region'].unique()
# Out:
# array(['EMRO', 'EURO', 'AFRO', 'WPRO', 'AMRO', 'SEARO', 'Other'],
#       dtype=object)

# %%
# Let's start analysing by region

data_americas = data[data['WHO_region'] == 'AMRO']

# %%
data_americas
# Out:
#        Date_reported Country_code                             Country  \
# 6708      2020-01-03           AI                            Anguilla
# 6709      2020-01-04           AI                            Anguilla
# 6710      2020-01-05           AI                            Anguilla
# 6711      2020-01-06           AI                            Anguilla
# 6712      2020-01-07           AI                            Anguilla
# ...              ...          ...                                 ...
# 259371    2023-01-20           VE  Venezuela (Bolivarian Republic of)
# 259372    2023-01-21           VE  Venezuela (Bolivarian Republic of)
# 259373    2023-01-22           VE  Venezuela (Bolivarian Republic of)
# 259374    2023-01-23           VE  Venezuela (Bolivarian Republic of)
# 259375    2023-01-24           VE  Venezuela (Bolivarian Republic of)
#
#        WHO_region  New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# ...

# %%
data_americas.groupby('Country')[(
    'Cumulative_deaths')].max()
# Out:
# Country
# Anguilla                                   12
# Antigua and Barbuda                       146
# Argentina                              130394
# Aruba                                     281
# Bahamas                                   833
# Barbados                                  569
# Belize                                    688
# Bermuda                                   157
# Bolivia (Plurinational State of)        22342
# Bonaire                                    33
# Brazil                                 696257
# British Virgin Islands                     64
# Canada                                  50135
# Cayman Islands                             37
# Chile                                   63683
# Colombia                               142385
# Costa Rica                               9142
# Cuba                                     8530
# Curaçao                                   301
# Dominica                                   74
# ...
