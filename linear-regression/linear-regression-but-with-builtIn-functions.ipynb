# %% [markdown]
# ## Day 2/100. In this exercice, I'm expecting to perform a linear regression using python libs for that

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv("weight-height.csv")
data
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
# Split the data based on gender

data_male = data[data["Gender"] == "Male"]
data_female = data[data["Gender"] == "Female"]

# %%
# Let's start working with the female data because I'm a gentleman

x = data_female["Height"]
y = data_female["Weight"]

# %%
# Dispersion of the data 

plt.xlabel('Height')
plt.ylabel('Weight')
plt.scatter(x, y);

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
x_train
# Out:
# 6650    61.865614
# 9442    64.718999
# 9080    67.079074
# 9538    65.008793
# 8418    65.658276
#           ...
# 7216    64.567796
# 9761    56.975279
# 6015    64.393693
# 5766    62.140689
# 6977    68.378205
# Name: Height, Length: 4000, dtype: float64

# %%
x_train = np.array(x_train).reshape(-1, 1)
x_train
# Out:
# array([[61.86561423],
#        [64.71899885],
#        [67.07907449],
#        ...,
#        [64.39369345],
#        [62.1406892 ],
#        [68.37820454]])

# %%
x_test = np.array(x_test).reshape(-1, 1)

# %%
regression = LinearRegression()
regression.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
c = regression.intercept_
m = regression.coef_

# %%
function_y = m*x_train+c
function_y
# Out:
# array([[124.82958269],
#        [142.10597139],
#        [156.39552207],
#        ...,
#        [140.13634473],
#        [126.49507917],
#        [164.26136517]])

# %%
#other way of doing the function_y

function_y2 = regression.predict(x_train)
function_y2
# Out:
# array([124.82958269, 142.10597139, 156.39552207, ..., 140.13634473,
#        126.49507917, 164.26136517])

# %%
plt.scatter(x_train, y_train, color="red")
plt.plot(x_train, function_y, color="black")
plt.xlabel("Height in inches")
plt.ylabel("Weight in pounds")
# Out:
# Text(0, 0.5, 'Weight in pounds')

# %%
# Now testing with the test data (previous one was with the train data)
function_y3 = regression.predict(x_test)
function_y3.flatten()
# Out:
# array([154.82295625, 122.55313303, 141.01770774, 145.68694693,
#        145.077767  , 102.30633107, 156.52728721, 157.41966929,
#        130.69747023, 117.6448547 , 135.222998  , 130.21086424,
#        114.59281063, 120.45552921, 128.67885811, 174.85980499,
#        167.64892257, 122.5640564 , 123.86555057, 125.45127999,
#        126.24119319, 141.82340262, 142.63583007, 130.06595926,
#        125.52773955, 153.76446291, 166.73387214, 142.86255448,
#         99.45776592, 143.67339496, 132.11220119, 123.53483141,
#        138.41507251, 157.75377878, 108.98468325, 139.556999  ,
#        124.87450164, 107.6381184 , 125.78244385, 146.71857331,
#        127.51424317, 148.36538526,  99.33487934, 150.77846109,
#        112.94980396, 120.71629058, 145.8920448 ,  99.60496163,
#        121.07696243, 129.23750353, 137.03786686, 137.9091171 ,
#        133.16764185, 109.53778942, 134.78676006, 138.13601563,
#        143.14084005, 124.5234578 , 124.5109286 , 120.73923681,
# ...

# %%
plt.scatter(x_test, y_test, color="yellow")
plt.plot(x_test, function_y3, color="black")
plt.xlabel("Height in inches")
plt.ylabel("Weight in pounds")
# Out:
# Text(0, 0.5, 'Weight in pounds')
